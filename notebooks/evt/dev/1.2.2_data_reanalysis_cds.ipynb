# %% [markdown]
# # Data

# %%
import autoroot
from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env.
import xarray as xr
import os

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data

# %% [markdown]
# **Climate Data Store**
#
# * ERA5 Land Daily Aggregates - "ECMWF/ERA5_LAND/DAILY_AGGR" - [GEE Link](https://developers.google.com/earth-engine/datasets/catalog/ECMWF_ERA5_LAND_DAILY_AGGR)
# * ERA5 Daily Aggregates - "ECMWF/ERA5/DAILY" - [GEE Link](https://developers.google.com/earth-engine/datasets/catalog/ECMWF_ERA5_DAILY)

# %%
pl_variables = ['t', 'u', 'v', 'z', 'r']
pl_levels = [1000, 925, 850, 700, 600, 500, 400, 300, 250, 200, 150, 100, 50]
sl_variables = ['u10m', 'v10m', 't2m', 'sp', 'msl', 'tcwv', 'u100m', 'v100m']

# %%
ds = xr.open_dataset(
    'ee://ECMWF/ERA5_LAND/DAILY_AGGR', 
    engine='ee',
    crs='EPSG:4326', 
    scale=0.25
)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                                                    (time: 27050,
#                                                                 lon: 1440,
#                                                                 lat: 720)
# Coordinates:
#   * time                                                       (time) datetime64[ns] ...
#   * lon                                                        (lon) float32 ...
#   * lat                                                        (lat) float32 ...
# Data variables: (12/150)
#     dewpoint_temperature_2m                                    (time, lon, lat) float64 ...
#     temperature_2m                                             (time, lon, lat) float64 ...
#     skin_temperature                                           (time, lon, lat) float64 ...
#     soil_temperature_level_1                                   (time, lon, lat) float64 ...
#     soil_temperature_level_2                                   (time, lon, lat) float64 ...
#     soil_temperature_level_3                                   (time, lon, lat) float64 ...
#     ...                                                         ...
#     total_precipitation_min                                    (time, lon, lat) float64 ...
#     total_precipitation_max                                    (time, lon, lat) float64 ...
#     leaf_area_index_high_vegetation_min                        (time, lon, lat) float64 ...
#     leaf_area_index_high_vegetation_max                        (time, lon, lat) float64 ...
#     leaf_area_index_low_vegetation_min                         (time, lon, lat) float64 ...
#     leaf_area_index_low_vegetation_max                         (time, lon, lat) float64 ...
# Attributes:
#     crs:      EPSG:4326

# %%
from pathlib import Path
save_dir = Path("/pool/proyectos/CLINT/bayesevt/data/era5/raw")
save_name = Path("era5_land_daily.nc")

# %%
ds.load()

# %%
ds.to_netcdf(save_dir.joinpath(save_name))
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/ee/data.py:402, in _execute_cloud_call(call, num_retries)
#     401 try:
# --> 402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine-highvolume.googleapis.com/v1/projects/earthengine-legacy/image:computePixels? returned "Total request size (56623104 bytes) must be less than or equal to 50331648 bytes.". Details: "Total request size (56623104 bytes) must be less than or equal to 50331648 bytes.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 ds.to_netcdf(save_dir.joinpath(save_name))
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/core/dataset.py:2303, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    2300     encoding = {}
#    2301 from xarray.backends.api import to_netcdf
# -> 2303 return to_netcdf(  # type: ignore  # mypy cannot resolve the overloads:(
#    2304     self,
#    2305     path,
#    2306     mode=mode,
#    2307     format=format,
#    2308     group=group,
#    2309     engine=engine,
#    2310     encoding=encoding,
#    2311     unlimited_dims=unlimited_dims,
#    2312     compute=compute,
#    2313     multifile=False,
#    2314     invalid_netcdf=invalid_netcdf,
#    2315 )
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/api.py:1315, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1310 # TODO: figure out how to refactor this logic (here and in save_mfdataset)
#    1311 # to avoid this mess of conditionals
#    1312 try:
#    1313     # TODO: allow this work (setting up the file for writing array data)
#    1314     # to be parallelized with dask
# -> 1315     dump_to_store(
#    1316         dataset, store, writer, encoding=encoding, unlimited_dims=unlimited_dims
#    1317     )
#    1318     if autoclose:
#    1319         store.close()
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/api.py:1362, in dump_to_store(dataset, store, writer, encoder, encoding, unlimited_dims)
#    1359 if encoder:
#    1360     variables, attrs = encoder(variables, attrs)
# -> 1362 store.store(variables, attrs, check_encoding, writer, unlimited_dims=unlimited_dims)
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/common.py:352, in AbstractWritableDataStore.store(self, variables, attributes, check_encoding_set, writer, unlimited_dims)
#     349 if writer is None:
#     350     writer = ArrayWriter()
# --> 352 variables, attributes = self.encode(variables, attributes)
#     354 self.set_attributes(attributes)
#     355 self.set_dimensions(variables, unlimited_dims=unlimited_dims)
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/common.py:441, in WritableCFDataStore.encode(self, variables, attributes)
#     438 def encode(self, variables, attributes):
#     439     # All NetCDF files get CF encoded by default, without this attempting
#     440     # to write times, for example, would fail.
# --> 441     variables, attributes = cf_encoder(variables, attributes)
#     442     variables = {k: self.encode_variable(v) for k, v in variables.items()}
#     443     attributes = {k: self.encode_attribute(v) for k, v in attributes.items()}
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/conventions.py:791, in cf_encoder(variables, attributes)
#     788 # add encoding for time bounds variables if present.
#     789 _update_bounds_encoding(variables)
# --> 791 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     793 # Remove attrs from bounds variables (issue #2921)
#     794 for var in new_vars.values():
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/conventions.py:791, in <dictcomp>(.0)
#     788 # add encoding for time bounds variables if present.
#     789 _update_bounds_encoding(variables)
# --> 791 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     793 # Remove attrs from bounds variables (issue #2921)
#     794 for var in new_vars.values():
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/conventions.py:192, in encode_cf_variable(var, needs_copy, name)
#     179 ensure_not_multiindex(var, name=name)
#     181 for coder in [
#     182     times.CFDatetimeCoder(),
#     183     times.CFTimedeltaCoder(),
#    (...)
#     190     variables.BooleanCoder(),
#     191 ]:
# --> 192     var = coder.encode(var, name=name)
#     194 # TODO(kmuehlbauer): check if ensure_dtype_not_object can be moved to backends:
#     195 var = ensure_dtype_not_object(var, name=name)
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/coding/times.py:809, in CFDatetimeCoder.encode(self, variable, name)
#     807 def encode(self, variable: Variable, name: T_Name = None) -> Variable:
#     808     if np.issubdtype(
# --> 809         variable.data.dtype, np.datetime64
#     810     ) or contains_cftime_datetimes(variable):
#     811         dims, data, attrs, encoding = unpack_for_encoding(variable)
#     813         units = encoding.pop("units", None)
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/core/variable.py:416, in Variable.data(self)
#     414     return self._data
#     415 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 416     return self._data.get_duck_array()
#     417 else:
#     418     return self.values
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/core/indexing.py:699, in MemoryCachedArray.get_duck_array(self)
#     698 def get_duck_array(self):
# --> 699     self._ensure_cached()
#     700     return self.array.get_duck_array()
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/core/indexing.py:693, in MemoryCachedArray._ensure_cached(self)
#     692 def _ensure_cached(self):
# --> 693     self.array = as_indexable(self.array.get_duck_array())
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/core/indexing.py:667, in CopyOnWriteArray.get_duck_array(self)
#     666 def get_duck_array(self):
# --> 667     return self.array.get_duck_array()
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/core/indexing.py:554, in LazilyIndexedArray.get_duck_array(self)
#     553 def get_duck_array(self):
# --> 554     array = self.array[self.key]
#     555     # self.array[self.key] is now a numpy array when
#     556     # self.array is a BackendArray subclass
#     557     # and self.key is BasicIndexer((slice(None, None, None),))
#     558     # so we need the explicit check for ExplicitlyIndexed
#     559     if isinstance(array, ExplicitlyIndexed):
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xee/ext.py:726, in EarthEngineBackendArray.__getitem__(self, key)
#     725 def __getitem__(self, key: indexing.ExplicitIndexer) -> np.typing.ArrayLike:
# --> 726   return indexing.explicit_indexing_adapter(
#     727       key,
#     728       self.shape,
#     729       indexing.IndexingSupport.BASIC,
#     730       self._raw_indexing_method,
#     731   )
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/core/indexing.py:861, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     839 """Support explicit indexing by delegating to a raw indexing method.
#     840
#     841 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#     858 Indexing result, in the form of a duck numpy-array.
#     859 """
#     860 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 861 result = raw_indexing_method(raw_key.tuple)
#     862 if numpy_indices.tuple:
#     863     # index the loaded np.ndarray
#     864     result = NumpyIndexingAdapter(result)[numpy_indices]
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xee/ext.py:844, in EarthEngineBackendArray._raw_indexing_method(self, key)
#     842 # TODO(#11): Allow users to configure this via kwargs.
#     843 with concurrent.futures.ThreadPoolExecutor() as pool:
# --> 844   for (i, j, k), arr in pool.map(
#     845       self._make_tile, self._tile_indexes(key[0], bbox)
#     846   ):
#     847     tiles[i][j][k] = arr
#     849 out = np.block(tiles)
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xee/ext.py:862, in EarthEngineBackendArray._make_tile(self, tile_index)
#     860 tile_idx, (istart, iend, *bbox) = tile_index
#     861 target_image = self._slice_collection(slice(istart, iend))
# --> 862 return tile_idx, self.store.image_to_array(
#     863     target_image, grid=self.store.project(tuple(bbox)), dtype=self.dtype
#     864 )
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xee/ext.py:463, in EarthEngineStore.image_to_array(self, image, pixels_getter, dtype, **kwargs)
#     457 image = image.unmask(self.mask_value)
#     458 params = {
#     459     'expression': image,
#     460     'fileFormat': 'NUMPY_NDARRAY',
#     461     **kwargs,
#     462 }
# --> 463 raw = common.robust_getitem(
#     464     pixels_getter, params, catch=ee.ee_exception.EEException
#     465 )
#     467 # Extract out the shape information from EE response.
#     468 y_size, x_size = raw.shape
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xarray/backends/common.py:151, in robust_getitem(array, key, catch, max_retries, initial_delay)
#     149 for n in range(max_retries + 1):
#     150     try:
# --> 151         return array[key]
#     152     except catch:
#     153         if n == max_retries:
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/xee/ext.py:92, in _GetComputedPixels.__getitem__(self, params)
#      91 def __getitem__(self, params) -> np.ndarray:
# ---> 92   return ee.data.computePixels(params)
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/ee/data.py:928, in computePixels(params)
#     924 params['fileFormat'] = _cloud_api_utils.convert_to_image_file_format(
#     925     converter.expected_data_format()
#     926 )
#     927 _maybe_populate_workload_tag(params)
# --> 928 data = _execute_cloud_call(
#     929     _get_cloud_projects_raw()
#     930     .image()
#     931     .computePixels(project=_get_projects_path(), body=params)
#     932 )
#     933 if converter:
#     934   return converter.do_conversion(data)
#
# File ~/miniconda/envs/bayesevt_ai/lib/python3.10/site-packages/ee/data.py:404, in _execute_cloud_call(call, num_retries)
#     402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
# --> 404   raise _translate_cloud_exception(e)
#
# EEException: Total request size (56623104 bytes) must be less than or equal to 50331648 bytes.

# %%
col

# %%
cat = col.search(
    source_id=["MPI-ESM1-2-HR", "MIROC6"],
    variable_id=["pr", "tas"],
    member_id="r1i1p1f1",  #
    table_id="day",
    grid_label="gn",
    experiment_id=["historical", "ssp126", "ssp245", "ssp585"],
    require_all_on=["experiment_id", "variable_id"],
)
kwargs = dict(
    preprocess=combined_preprocessing, xarray_open_kwargs=dict(use_cftime=True)
)
ds_dict = cat.to_dataset_dict(zarr_kwargs={"consolidated": True})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cat = col.search(
#       2     source_id=["MPI-ESM1-2-HR", "MIROC6"],
#       3     variable_id=["pr", "tas"],
#       4     member_id="r1i1p1f1",  #
#       5     table_id="day",
#       6     grid_label="gn",
#       7     experiment_id=["historical", "ssp126", "ssp245", "ssp585"],
#       8     require_all_on=["experiment_id", "variable_id"],
#       9 )
#      10 kwargs = dict(
#      11     preprocess=combined_preprocessing, xarray_open_kwargs=dict(use_cftime=True)
#      12 )
#      13 ds_dict = cat.to_dataset_dict(zarr_kwargs={"consolidated": True})
#
# NameError: name 'col' is not defined

# %%
sel_Hamburg = dict(lon=10, lat=53.5)
sel_Madrid = dict(lon=360 - 42, lat=40.5)
sel_Delhi = dict(lon=77, lat=28.5)
sel_Kinshasa = dict(lon=15, lat=-4)
sel_Phoenix = dict(lon=360 - 112, lat=33.5)
sel_Sydney = dict(lon=151, lat=-33.85)

sels = dict(
    Hamburg=sel_Hamburg,
    Madrid=sel_Madrid,
    Delhi=sel_Delhi,
    Kinshasa=sel_Kinshasa,
    Phoenix=sel_Phoenix,
    Sydney=sel_Sydney,
)
